# %% [markdown]
# ### Day36.YOLO 細節理解-網絡架構
# 用實際的影像，嘗試自己搭建一個 1乘1和 3乘 3的模型
# 看通過 1乘1和 3乘3 卷積層後會有甚麼變化?
# 大家可以自己嘗試著搭建不同層數後，觀察圖形特徵的變化

# %%
#宣告
import cv2
import matplotlib.patches as patches
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras import backend as K
from keras.models import Sequential 
from keras.layers.core import Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
# Out:
# Using TensorFlow backend.

# %%
##讀入照片
# 下載圖片範例，如果已經下載過就可以註解掉
# !wget https://github.com/pjreddie/darknet/blob/master/data/dog.jpg?raw=true -O dog.jpg
image=cv2.imread('dog.jpg')
#ax.imshow(image)

def show(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # plt.imshow 預設圖片是 rgb 的
    plt.show()
show(image)
# Out:
# --2020-01-13 14:54:57--  https://github.com/pjreddie/darknet/blob/master/data/dog.jpg?raw=true
# 正在查找主機 github.com (github.com)... 140.82.113.4
# 正在連接 github.com (github.com)|140.82.113.4|:443... 連上了。
# 已送出 HTTP 要求，正在等候回應... 302 Found
# 位置: https://github.com/pjreddie/darknet/raw/master/data/dog.jpg [跟隨至新的 URL]
# --2020-01-13 14:54:59--  https://github.com/pjreddie/darknet/raw/master/data/dog.jpg
# 繼續使用和 github.com:443 的連線。
# 已送出 HTTP 要求，正在等候回應... 302 Found
# 位置: https://raw.githubusercontent.com/pjreddie/darknet/master/data/dog.jpg [跟隨至新的 URL]
# --2020-01-13 14:54:59--  https://raw.githubusercontent.com/pjreddie/darknet/master/data/dog.jpg
# 正在查找主機 raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# 正在連接 raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... 連上了。
# 已送出 HTTP 要求，正在等候回應... 200 OK
# 長度: 163759 (160K) [image/jpeg]
# 儲存到：`dog.jpg'
#
# dog.jpg             100%[===================>] 159.92K  --.-KB/s  於 0.1s
#
# 2020-01-13 14:55:00 (1.10 MB/s) - 已儲存 `dog.jpg' [163759/163759]

# %%
# create model
#Sequential 是一個多層模型
#透過 add() 函式將一層一層 layer 加上去
#data_format='channels_last' 尺寸为 (batch, rows, cols, channels)
#搭建一個 3 個 1*1 的 filters
model=Sequential()
model.add(Conv2D(3,
                 (1,1),
          padding="same",
         data_format='channels_last',
         activation='relu',
         input_shape=image.shape))
#作業: 接續搭建一個 4 個 3*3 的 filters 
model.add(Conv2D(4,(3,3),
           padding = 'same',
           data_format = 'channels_last',
           activation = 'relu',
           input_shape = image.shape))



print(model.summary())
#權重都是亂數值
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 576, 768, 3)       12
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 576, 768, 4)       112
# =================================================================
# Total params: 124
# Trainable params: 124
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# keras 在讀取檔案實是以 batch 的方式一次讀取多張，
#但我們這裡只需要判讀一張，
#所以透過 expand_dims() 函式來多擴張一個維度
image_batch=np.expand_dims(image,axis=0)
print(image_batch.shape)
# Out:
# (1, 576, 768, 3)

# %%
#model.predict() 函式，得到回傳便是 feature map
image_conv=model.predict(image_batch)
img=np.squeeze(image_conv,axis=0)
print(img.shape)
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (576, 768, 4)

# %% [markdown]
# #### 由於權重都是亂數值，所以每次跑出來的結果不同
# 大家可以自己嘗試著搭建不同層數後，觀察圖形特徵的變化
