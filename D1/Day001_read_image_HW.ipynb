# %% [markdown]
# # 作業
#
# 思考一下我們前面有提到圖片是矩陣，但維度可能會不一樣
# 例如灰階圖只有兩個維度，RGB 彩圖則有 3 個維度
#
# 假如今天我們把 RGB 3 個維度拆開來看會有甚麼不同的效果呢？

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = '../Part01/lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
B,G,R = cv2.split(img)
plt.subplot(1,3,1)
plt.imshow(B)
plt.subplot(1,3,2)
plt.imshow(G)
plt.subplot(1,3,3)
plt.imshow(R)

# plt.imshow('GREEN',G)
# plt.imshow('BLUE',B)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
plt.show()

# %%
print('image shape', img.shape)
print('R image shape',R.shape)
# Out:
# image shape (512, 512, 3)
# R image shape (512, 512)

# %%
import cv2

img_path = '../Part01/lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
#CV2 --> B,G,R; plt --> R,G,B 
print(img.shape)

img_R = img.copy()
imgB[...,1] = 0
imgB[...,2] = 0

img_G = img.copy()
imgG[...,0] = 0
imgG[...,2] = 0

img_B = img.copy()
imgR[...,0] = 0
imgR[...,1] = 0

plt.subplot(1,3,1)
plt.imshow(imgB)
plt.subplot(1,3,2)
plt.imshow(imgG)
plt.subplot(1,3,3)
plt.imshow(imgR)
# Out:
# (512, 512, 3)
